# %%
# Example-1 -> Create a base class Shape with method area(). Implement subclasses Rectangle and Circle that
# calculate area differently. Use polymorphism to call area method.

import math

class Shape:
    def area(self):
        pass

class Rectangle(Shape):
    def __init__ (self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius * self.radius

def calculate_area(find_area):
    return find_area.area()

rectangle = Rectangle(4,5)
circle = Circle(5)

print("Area of Rectangle :", calculate_area(rectangle))
print("Area of Circle :", calculate_area(circle))
# Out:
# Area of Rectangle : 20
# Area of Circle : 78.53981633974483

# %%
# Example-2 -> Implement a class Vehicle with method start(). Create subclasses Car and Bike overriding the start
# method. Write a function that takes any vehicle object and calls its start.

class Vehicle:
    def start(self):
        print("Vehicle is starting!")

class Car(Vehicle):
    def start(self):
        print("Car is starting!")

class Bike(Vehicle):
    def start(self):
        print("Bike is starting!")

def start_vehicle(starting):
    starting.start()

car = Car()
bike = Bike()

start_vehicle(car)
start_vehicle(bike)
# Out:
# Car is starting!
# Bike is starting!

# %%
# Example-3 -> Define a class Employee with __str__ method for printing. Override the __add__ operator to add the 
# salaries of two employees.

class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

    def __str__(self):
        return f"Employee Name : {self.name}, Salary : {self.salary}"

    def __add__(self, other):
        if isinstance(other, Employee):
            return self.salary + other.salary
        return NotImplemented

emp1 = Employee("Alice", 600)
emp2 = Employee("Bob", 700)

print(emp1)
print(emp2)

total_salary = emp1 + emp2
print("Total Salary :", total_salary)
# Out:
# Employee Name : Alice, Salary : 600
# Employee Name : Bob, Salary : 700
# Total Salary : 1300

# %%
# Q4: Create classes Printer and Scanner with method device_type() printing their types. Write a function that 
# accepts an object and prints its device type, demonstrating duck typing.

class Printer:
    def device_type(self):
        print("It is an Output Device!")

class Scanner:
    def device_type(self):
        print("It is an Input Device!")

def show_type(device):
    device.device_type()

printer = Printer()
scanner = Scanner()

show_type(printer)
show_type(scanner)
# Out:
# It is an Output Device!
# It is an Input Device!

# %%
# Create a base class Report with an abstract method generate(). Subclasses PDFReport, ExcelReport, and HTMLReport
# should implement generate() differently. Write a function that takes a list of reports and calls generate() 
# polymorphically.

class Report:
    def generate(self):
        pass

class PDFReport(Report):
    def generate(
