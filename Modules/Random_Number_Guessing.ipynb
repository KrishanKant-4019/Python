# %%
import random

print("\n-------Welcome to the Number Guessing Game-------")

while True:
    random_number = random.randint(1, 20)
    attempts = 0
    
    while True:
        try:
            choice = int(input("Enter your choice(1-20):"))

            if choice < 1 or choice > 20:
                print("Please enter a number between 1 and 20.")
                continue
                
            attempts += 1
            if choice < random_number:
                print("Too low! You're so close, Please try again!")

            elif choice > random_number:
                print("Too high! You're so close, Please try again!")

            else:
                print(f"Congrats! You guessed right in {attempts} attempts.")
                break
            
        except ValueError:
            print("Invalid Input!Please enter a number.")

    play_again = input("Do you want to play again?(Yes/No)").strip().lower()
    if play_again not in ("yes", "y"):
        print("Thanks for playing!Goodbye")
        break
# Out:
# -------Welcome to the Number Guessing Game-------
# Enter your choice(1-20): 15
# Too high! You're so close, Please try again!
# Enter your choice(1-20): 10
# Too high! You're so close, Please try again!
# Enter your choice(1-20): 5
# Too low! You're so close, Please try again!
# Enter your choice(1-20): 61
# Please enter a number between 1 and 20.
# Enter your choice(1-20): 7
# Too low! You're so close, Please try again!
# Enter your choice(1-20): 8
# Congrats! You guessed right in 5 attempts.
# Do you want to play again?(Yes/No) No
# Thanks for playing!Goodbye
