# %%
# Import the datetime module and display the current date:
import datetime

x=datetime.datetime.now()
print(x)
print(x.year) #Return the year
print(x.strftime("%A")) #Return the name of weekday:
# Out:
# 2025-05-20 14:14:52.877752
# 2025
# Tuesday

# %%
# Creating Date Objects
y=datetime.datetime(2025,5,20)
print(y)
# Out:
# 2025-05-20 00:00:00

# %%
# The strftime() Method
z=datetime.datetime.now()
print(z.strftime("%B")) #Return the name of month
# Out:
# May
